# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.figure(figsize=(10, 6), dpi=300)
for i in range(1, 101):
    df = pd.read_csv('Simulation_BENDING/CONSTANT_THICKNESS_100/BENDING_X_data.csv/BENDING_'+str(i)+'_data.csv')
    plt.plot(df['DMM'], df['FKN'], linewidth=1, color='tab:blue')
for i in range(1, 51):
    df = pd.read_csv('Simulation_BENDING/VARIABLE_THICKNESS_50/BENDING_X_data.csv/BENDING_'+str(i)+'_data.csv')
    plt.plot(df['DMM'], df['FKN'], linewidth=1, color='tab:orange')
"""for i in range(1,2):
    df = pd.read_csv('Simulation_BENDING/MEAN_VALUES_2/BENDING_X_data.csv/BENDING_'+str(i)+'_data.csv')
    plt.plot(df['DMM'], df['FKN'], linewidth=2.5, color='g')"""

plt.xlabel('Displacement (mm)', fontsize=18)
plt.ylabel('Force (kN)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid()
plt.show()

# Red: The standard without variable thickness
# Blue: Variable thickness
# Green: Middle value without variable thickness

# %%
plt.figure(figsize=(10, 6), dpi=300)
for i in range(1, 101):
    df = pd.read_csv('Simulation_CRUSHING/CONSTANT_THICKNESS_100/CRUSHING_X_data.csv/CRUSHING_'+str(i)+'_data.csv')
    plt.plot(df['DMM'], df['FKN'], linewidth=1, color='tab:blue')
for i in range(1, 51):
    df = pd.read_csv('Simulation_CRUSHING/VARIABLE_THICKNESS_50/CRUSHING_X_data.csv/CRUSHING_'+str(i)+'_data.csv')
    plt.plot(df['DMM'], df['FKN'], linewidth=1, color='tab:orange')
"""for i in range(1,2):
    df = pd.read_csv('Simulation_CRUSHING/MEAN_VALUES_2/CRUSHING_X_data.csv/CRUSHING_'+str(i)+'_data.csv')
    plt.plot(df['DMM'], df['FKN'], linewidth=2.5, color='g')"""

plt.xlabel('Displacement (mm)', fontsize=18)
plt.ylabel('Force (kN)', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.grid()
plt.show()
